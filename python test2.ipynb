# %%
## write a program to check if a given string is a palindrome

def is_palindrome(s):
    return s == s[::-1]

a = input("Enter a value ")

if is_palindrome(a):
    print("It's a palindrome")
else:
    print("It's not a palindrome")
# Out:
# Enter a value  madam
# It's a palindrome

# %%
# Program to calculate factorial of a number using loops

num = int(input("Enter a number"))
factorial = 1
if num < 0:
    print("factorial does not exist for negative numbers.")
elif num == 0:
    print("The factorial of 0 is 1.")
else:
    for i in range(1, num + 1):
        factorial *= i
    print(f"The factorial of {num} is {factorial}")
# Out:
# Enter a number 34
# The factorial of 34 is 295232799039604140847618609643520000000

# %%
## given year is a leap year or not
n = int(input("please enter the number"))
if n%4==0:
    print("it is a leap year")
else:
    print("it is not a leap year")
# Out:
# please enter the number 2023
# it is not a leap year

# %%
# Program to print the Fibonacci sequence up to n terms
n = int(input("Enter the number of terms: "))
a, b = 0, 1
print("Fibonacci sequence:")
for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter the number of terms:  8
# Fibonacci sequence:
# 0 1 1 2 3 5 8 13

# %%
# Function to calculate GCD of two numbers
def gcd(a, b):
    while b != 0:
        a, b = b, a % b
    return a
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
print(f"The GCD of {num1} and {num2} is {gcd(num1, num2)}")
# Out:
# Enter first number:  48
# Enter second number:  16
# The GCD of 48 and 16 is 16

# %%
# Recursive function to calculate the nth Fibonacci number
def fibonacci(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)
n = int(input("Enter the value of n: "))
print(f"The {n}th Fibonacci number is {fibonacci(n)}")
# Out:
# Enter the value of n:  7
# The 7th Fibonacci number is 13

# %%
# lambda function to return squares of list of num
numbers = [1, 2, 3, 4, 5]
squares = list(map(lambda x: x**2, numbers))
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
## write a fun using *args and **kwargs
def display_info(*args, **kwargs):
    print("Positional arguments:", args)
    print("Keyword arguments:", kwargs)

display_info(10, 20, 30, name="Alice", age=25, city="New York")
# Out:
# Positional arguments: (10, 20, 30)
# Keyword arguments: {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %%
# Program to read a text file and print its contents
f=open('I love programming.txt','r')
content=(f.read())
print(content)
# Out:
# I love programmingg

# %%
## program to handle zerodivisionerror using try-except
try:
    a=int(input("enter a number"))
    b=int(input("enter a number"))
    c=a/b
    print(c)
except ZeroDivisionError:
    print("b should not be a zero")
# Out:
# enter a number 23
# enter a number 45
# 0.5111111111111111

# %%
## program to write user input to a file 
with open('python.txt','w') as f:
    f.write("python is awesome")
    f.write("i love python")

# %%
## carclass
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def display_details(self):
        print(f"Car Brand: {self.brand}")
        print(f"Car Model: {self.model}")
car1 = Car("Toyota", "Corolla")
car2 = Car("Tesla", "Model 3")

car1.display_details()
print()  # For spacing
car2.display_details()
# Out:
# Car Brand: Toyota
# Car Model: Corolla
#
# Car Brand: Tesla
# Car Model: Model 3
